# %% [markdown]
# # Data Scraping
#
# We will use requests and BeautifulSoup for data scraping

# %%
import requests
from bs4 import BeautifulSoup

# %%
'''Import the website for page of any business or service provider from yelp.com here'''
#r = requests.get("")
#making request to get the data



'''Samples'''
#r = requests.get("https://www.yelp.com/biz/current-solutions-electric-kansas-city?override_cta=Request+a+Quote")
#r = requests.get("https://www.yelp.com/biz/topgolf-overland-park-2")
#r = requests.get("https://www.yelp.com/biz/the-ceiling-fan-man-electrical-service-edgerton?override_cta=Request+a+Quote")

r = requests.get("https://www.yelp.com/biz/cicis-pizza-liberty-4")

# %%
r.status_code #checking the status of our request. Status of 200 means the request was successful
# Out:
# 200

# %%
##But it doesn't give text to read the data. So, converting the requested data to text
r.text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 2
#       1 ##But it doesn't give text to read the data. So, converting the requested data to text
# ----> 2 r.text
#
# NameError: name 'r' is not defined

# %%
#now parsing through the html page

soup = BeautifulSoup(r.text, 'html.parser')

# %%
#lets find the class of the section with reviews in html elements
divs = soup.find_all(class_= "comment__09f24__D0cxf css-qgunke")

# %%
#lets look at the filtered html elements

for div in divs:
   print(div.prettify())

# %%
#Lets only get the texts of reviews
for div in divs:
    print(div.text, '\n')

# %%
#creating an array of reviews
reviews = []
for div in divs:
    reviews.append(div.text)

# %%
reviews
# Out:
# ["It's a thursday afternoon and this Cici's is clean, well-stocked; and being run solo by one lady. The country is a little loud but hey, it's missouri. Got lunch and got out and had a chill time doing it.Edit: For Management / Owners: The women's restroom needs some TLC in order for it to feel like a safe, comfortable space. The seats should be replaced and one of the walls needs to be re-affixed to the door before it hurts someone, there are screws sticking out and easily accessible in a space frequented by children.",
#  'What a joke of a business surprise to see them still in business every time you go there they closing early and pizza lame',
#  'love this place, i totally recommend to all pizza lovers i had to come here for my school trip but i still love it',
#  "Everyone knows that this place has subpar pizza but sometimes as parents we look past that because of the cheap price.  My biggest gripes are that they don't take responsibility for everything in their building.  Something as simple as the token machine they have.  They have a token machine to buy tokens.  One would think that the video games they have there would run off those tokens.  But when you finally approach the video games they don't run off of tokens but you have to buy a card and charge it to play video games.  I approached the manager about getting a refund.  I would take that refund and then buy the video game cards.  But all I got was the answer that those are n ot owned by cities.  We don't take responsibility for the video games since it is an outside company that runs and owns them.  How difficult would it be for them to give me my refund or whoever this happens to and then them work out all the refunds they had to give with that company that they allow to bring in video games to their restaurant?  Instead they would rather let this lose them business.  What this type of thing does is create a ton of one time customers.  It definitely does not create repeat customers.",
#  'I have not been to a cc pizza since I was in college in Springfield Missouri over two decades ago. Quite honestly not much has changed. I do have to say that back in the day they did not have pasta and the salad bar was not as extensive as it is now. I enjoyed every minute of reliving the nostalgia of my college years. The manager that was working was fantastic and really nice. She made my favorite pizza which is the barbecue beef pizza and I enjoyed it thoroughly. What a wonderful experience and a very clean and nice restaurant.',
#  "I am so impressed with the management of this shop, was greeted when we walked in, paid for the buffet and asked if there was any kind of pizza that we would like and I jokingly said anchovy and with a smile she said that they could make one, she said it's not requested often so she would make me a personal pizza. I had a bowl of soup and a salad while I waited, the soup was hot and the salad was fresh and cold, worth the price right there. Watching the crew work, they were engaged, positive and busy. The manager brought out the anchovy pizza and it was amazing, hot, fresh, and delicious. It had been awhile since we had been there but already planning out next trip",
#  "Rediculous, spend $9 on buffet without drink and can't get cheese for my salad.  El cheapo. It's paper thin pizza people. The lettuce was iceberg and chunky with brown all over it! Not a fan.",
#  'Way overpriced for a very small buffet with mediocre pizza, pasta, and "desert"... which none of the three or four options were really desert.Service was quick and easy and place seemed pretty clean. However, there\'s not anything else I can really compliment or give a thumbs up to.',
#  'Yummy pizza. This location is new and clean. They let you request pizzas with toppings you like- ready in 10 minutes. They gave a lot of varieties ready and fresh.Salad bar available too!',
#  "This place is discussing and nothing it clean they don't wash the try's they cook the pizzas on unless it falls on the floor the over hasn't been cleaned in years there's mold everywhere they failed 3 straight inspections and had to spray paint the vents to pass the next, how sad :("]

# %% [markdown]
# Lets Start calculating metrices

# %% [markdown]
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# # Data Analysis with key metrices

# %% [markdown]
# First, lets get this data in a dataframe

# %%
import pandas as pd
import numpy as np

# %%
##converting the array into a numpy array (we can skip this if we want to but numpy arrays consume less memory and convenient to use) 
# and then into a dataframe

df = pd.DataFrame(np.array(reviews), columns = ['reviews'])
df
# Out:
#                                              reviews
# 0  It's a thursday afternoon and this Cici's is c...
# 1  What a joke of a business surprise to see them...
# 2  love this place, i totally recommend to all pi...
# 3  Everyone knows that this place has subpar pizz...
# 4  I have not been to a cc pizza since I was in c...
# 5  I am so impressed with the management of this ...
# 6  Rediculous, spend $9 on buffet without drink a...
# 7  Way overpriced for a very small buffet with me...
# 8  Yummy pizza. This location is new and clean. T...
# 9  This place is discussing and nothing it clean ...

# %%
#looking at how many reiews are there
len(df)
# Out:
# 10

# %% [markdown]
# ### 1st metric we will use is word count of a review

# %%
#lets find the word count to get a better gaze at how much detail there might be in a review
df["reviews"].apply(lambda x: len(x.split()))
# Out:
# 0     95
# 1     24
# 2     24
# 3    222
# 4    102
# 5    131
# 6     35
# 7     48
# 8     33
# 9     53
# Name: reviews, dtype: int64

# %%
#Lets add the word count column in the dataframe
df["word_count"] = df["reviews"].apply(lambda x: len(x.split()))
df
# Out:
#                                              reviews  word_count
# 0  It's a thursday afternoon and this Cici's is c...          95
# 1  What a joke of a business surprise to see them...          24
# 2  love this place, i totally recommend to all pi...          24
# 3  Everyone knows that this place has subpar pizz...         222
# 4  I have not been to a cc pizza since I was in c...         102
# 5  I am so impressed with the management of this ...         131
# 6  Rediculous, spend $9 on buffet without drink a...          35
# 7  Way overpriced for a very small buffet with me...          48
# 8  Yummy pizza. This location is new and clean. T...          33
# 9  This place is discussing and nothing it clean ...          53

# %% [markdown]
# ### 2nd metric is character count of review

# %%
#using lambda function to count the number of characters in each row of reviews column
df["char_count"] = df["reviews"].apply(lambda x: len(x))
df
# Out:
#                                              reviews  word_count  char_count
# 0  It's a thursday afternoon and this Cici's is c...          95         522
# 1  What a joke of a business surprise to see them...          24         122
# 2  love this place, i totally recommend to all pi...          24         114
# 3  Everyone knows that this place has subpar pizz...         222        1203
# 4  I have not been to a cc pizza since I was in c...         102         535
# 5  I am so impressed with the management of this ...         131         673
# 6  Rediculous, spend $9 on buffet without drink a...          35         191
# 7  Way overpriced for a very small buffet with me...          48         282
# 8  Yummy pizza. This location is new and clean. T...          33         187
# 9  This place is discussing and nothing it clean ...          53         283

# %% [markdown]
# ### Average length of each word in a review

# %%
#creating an average word function
def average_words(x):
    words = x.split() #splitting the words 
    return sum(len(word) for word in words) / len(words) #what it does is add the length of each word divided by the total number of words

#it took me sometime as why we need this function? why can't we just do char_count / word_count. If we do that, 
# we will also include " " in between words which is included in char_count

# %%
df["average_word_length"] = df["reviews"].apply(lambda x: average_words(x))

# %% [markdown]
# ### 3rd metric is number of stop words

# %% [markdown]
# Stop words are words which add liitle to no meaning in review. Examples I, us, are etc.
# We need to strip these out later.
#
# For this, we will import a stop word list using a Natural Language Toolkit

# %%
##I didn't have nltk in my environment. So, I installed it in the anaconda environment from termial

# %%
import nltk
nltk.download('stopwords')
#I had to download the stopwords  as txt file because I got error of size limit.
# Out:
# [nltk_data] Downloading package stopwords to /Users/supg/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english') #stopwords for english
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
len(stop_words)
# Out:
# 179

# %%
df['stopword_count'] = df['reviews'].apply(lambda x: len([word for word in x.split() if word.lower() in stop_words]))
#what we did is applied lambda function to get the length of words (lower cased) in the reviews who exist in the stop_words
df
# Out:
#                                              reviews  word_count  char_count  \
# 0  It's a thursday afternoon and this Cici's is c...          95         522
# 1  What a joke of a business surprise to see them...          24         122
# 2  love this place, i totally recommend to all pi...          24         114
# 3  Everyone knows that this place has subpar pizz...         222        1203
# 4  I have not been to a cc pizza since I was in c...         102         535
# 5  I am so impressed with the management of this ...         131         673
# 6  Rediculous, spend $9 on buffet without drink a...          35         191
# 7  Way overpriced for a very small buffet with me...          48         282
# 8  Yummy pizza. This location is new and clean. T...          33         187
# 9  This place is discussing and nothing it clean ...          53         283
#
#    average_word_length  stopword_count
# 0             4.505263              46
# 1             4.125000              11
# 2             3.791667              13
# 3             4.364865             117
# 4             4.254902              56
# 5             4.145038              70
# 6             4.457143              13
# 7             4.895833              19
# 8             4.696970              12
# 9             4.358491              26

# %% [markdown]
# ### 4th metric is % of stop word

# %%
df['stopword_rate'] = df['stopword_count'] / df['word_count'] #calculating percentage (in decimal)
df
# Out:
#                                              reviews  word_count  char_count  \
# 0  It's a thursday afternoon and this Cici's is c...          95         522
# 1  What a joke of a business surprise to see them...          24         122
# 2  love this place, i totally recommend to all pi...          24         114
# 3  Everyone knows that this place has subpar pizz...         222        1203
# 4  I have not been to a cc pizza since I was in c...         102         535
# 5  I am so impressed with the management of this ...         131         673
# 6  Rediculous, spend $9 on buffet without drink a...          35         191
# 7  Way overpriced for a very small buffet with me...          48         282
# 8  Yummy pizza. This location is new and clean. T...          33         187
# 9  This place is discussing and nothing it clean ...          53         283
#
#    average_word_length  stopword_count  stopword_rate
# 0             4.505263              46       0.484211
# 1             4.125000              11       0.458333
# 2             3.791667              13       0.541667
# 3             4.364865             117       0.527027
# 4             4.254902              56       0.549020
# 5             4.145038              70       0.534351
# 6             4.457143              13       0.371429
# 7             4.895833              19       0.395833
# 8             4.696970              12       0.363636
# 9             4.358491              26       0.490566

# %%
df.sort_values(by = 'stopword_rate') #sorting by the stopword rate
# Out:
#                                              reviews  word_count  char_count  \
# 8  Yummy pizza. This location is new and clean. T...          33         187
# 6  Rediculous, spend $9 on buffet without drink a...          35         191
# 7  Way overpriced for a very small buffet with me...          48         282
# 1  What a joke of a business surprise to see them...          24         122
# 0  It's a thursday afternoon and this Cici's is c...          95         522
# 9  This place is discussing and nothing it clean ...          53         283
# 3  Everyone knows that this place has subpar pizz...         222        1203
# 5  I am so impressed with the management of this ...         131         673
# 2  love this place, i totally recommend to all pi...          24         114
# 4  I have not been to a cc pizza since I was in c...         102         535
#
#    average_word_length  stopword_count  stopword_rate
# 8             4.696970              12       0.363636
# 6             4.457143              13       0.371429
# 7             4.895833              19       0.395833
# 1             4.125000              11       0.458333
# 0             4.505263              46       0.484211
# 9             4.358491              26       0.490566
# 3             4.364865             117       0.527027
# 5             4.145038              70       0.534351
# 2             3.791667              13       0.541667
# 4             4.254902              56       0.549020

# %%
df.describe() #looking at statistical parameters
# Out:
#        word_count  char_count  average_word_length  stopword_count  \
# count   10.000000    10.00000            10.000000       10.000000
# mean    76.700000   411.20000             4.359517       38.300000
# std     62.914492   337.79277             0.310324       34.660416
# min     24.000000   114.00000             3.791667       11.000000
# 25%     33.500000   188.00000             4.172504       13.000000
# 50%     50.500000   282.50000             4.361678       22.500000
# 75%    100.250000   531.75000             4.493233       53.500000
# max    222.000000  1203.00000             4.895833      117.000000
#
#        stopword_rate
# count      10.000000
# mean        0.471607
# std         0.071522
# min         0.363636
# 25%         0.411458
# 50%         0.487388
# 75%         0.532520
# max         0.549020

# %% [markdown]
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# # Data Cleaning/ Prepping

# %% [markdown]
# ### Lowercasing words

# %%
df['reviews'].apply(lambda x: " ".join(word.lower() for word in x.split()))

#what we did is we first split the words in reviews, then lowered them and then joined them back with " " in between to get the whole sentences
# Out:
# 0    it's a thursday afternoon and this cici's is c...
# 1    what a joke of a business surprise to see them...
# 2    love this place, i totally recommend to all pi...
# 3    everyone knows that this place has subpar pizz...
# 4    i have not been to a cc pizza since i was in c...
# 5    i am so impressed with the management of this ...
# 6    rediculous, spend $9 on buffet without drink a...
# 7    way overpriced for a very small buffet with me...
# 8    yummy pizza. this location is new and clean. t...
# 9    this place is discussing and nothing it clean ...
# Name: reviews, dtype: object

# %%
#lets save the above change into a new column
df['lowercase'] = df['reviews'].apply(lambda x: " ".join(word.lower() for word in x.split()))
df
# Out:
#                                              reviews  word_count  char_count  \
# 0  It's a thursday afternoon and this Cici's is c...          95         522
# 1  What a joke of a business surprise to see them...          24         122
# 2  love this place, i totally recommend to all pi...          24         114
# 3  Everyone knows that this place has subpar pizz...         222        1203
# 4  I have not been to a cc pizza since I was in c...         102         535
# 5  I am so impressed with the management of this ...         131         673
# 6  Rediculous, spend $9 on buffet without drink a...          35         191
# 7  Way overpriced for a very small buffet with me...          48         282
# 8  Yummy pizza. This location is new and clean. T...          33         187
# 9  This place is discussing and nothing it clean ...          53         283
#
#    average_word_length  stopword_count  stopword_rate  \
# 0             4.505263              46       0.484211
# 1             4.125000              11       0.458333
# 2             3.791667              13       0.541667
# 3             4.364865             117       0.527027
# 4             4.254902              56       0.549020
# 5             4.145038              70       0.534351
# 6             4.457143              13       0.371429
# 7             4.895833              19       0.395833
# 8             4.696970              12       0.363636
# 9             4.358491              26       0.490566
#
#                                            lowercase
# 0  it's a thursday afternoon and this cici's is c...
# 1  what a joke of a business surprise to see them...
# 2  love this place, i totally recommend to all pi...
# 3  everyone knows that this place has subpar pizz...
# 4  i have not been to a cc pizza since i was in c...
# 5  i am so impressed with the management of this ...
# 6  rediculous, spend $9 on buffet without drink a...
# 7  way overpriced for a very small buffet with me...
# 8  yummy pizza. this location is new and clean. t...
# 9  this place is discussing and nothing it clean ...

# %% [markdown]
# ### Removing punctuations
# we dont need them to find sentiments

# %%
df['punctuation'] = df['lowercase'].str.replace('[^\w\s]', '')
df

#The regular expression [^\w\s] is a character class that matches a single character that is neither a word character (
# alphanumeric or underscore) nor a whitespace character.

# [ ]: Denotes a character class, meaning "match any one of the characters inside the brackets."
# ^: When used as the first character inside a character class, it negates the character class. 
# So, [^...] means "match any character that is not in the list."
# \w: Represents a word character (alphanumeric or underscore).
# \s: Represents a whitespace character (space, tab, newline).
# Out:
# /var/folders/qm/0l02t1ks0nz7t3l19pg05n9r0000gn/T/ipykernel_27996/2931249690.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['punctuation'] = df['lowercase'].str.replace('[^\w\s]', '')
#                                              reviews  word_count  char_count  \
# 0  It's a thursday afternoon and this Cici's is c...          95         522
# 1  What a joke of a business surprise to see them...          24         122
# 2  love this place, i totally recommend to all pi...          24         114
# 3  Everyone knows that this place has subpar pizz...         222        1203
# 4  I have not been to a cc pizza since I was in c...         102         535
# 5  I am so impressed with the management of this ...         131         673
# 6  Rediculous, spend $9 on buffet without drink a...          35         191
# 7  Way overpriced for a very small buffet with me...          48         282
# 8  Yummy pizza. This location is new and clean. T...          33         187
# 9  This place is discussing and nothing it clean ...          53         283
#
#    average_word_length  stopword_count  stopword_rate  \
# 0             4.505263              46       0.484211
# 1             4.125000              11       0.458333
# 2             3.791667              13       0.541667
# 3             4.364865             117       0.527027
# 4             4.254902              56       0.549020
# 5             4.145038              70       0.534351
# 6             4.457143              13       0.371429
# 7             4.895833              19       0.395833
# 8             4.696970              12       0.363636
# 9             4.358491              26       0.490566
#
#                                            lowercase  \
# 0  it's a thursday afternoon and this cici's is c...
# 1  what a joke of a business surprise to see them...
# 2  love this place, i totally recommend to all pi...
# 3  everyone knows that this place has subpar pizz...
# 4  i have not been to a cc pizza since i was in c...
# 5  i am so impressed with the management of this ...
# 6  rediculous, spend $9 on buffet without drink a...
# 7  way overpriced for a very small buffet with me...
# 8  yummy pizza. this location is new and clean. t...
# 9  this place is discussing and nothing it clean ...
#
#                                          punctuation
# 0  its a thursday afternoon and this cicis is cle...
# 1  what a joke of a business surprise to see them...
# 2  love this place i totally recommend to all piz...
# 3  everyone knows that this place has subpar pizz...
# 4  i have not been to a cc pizza since i was in c...
# 5  i am so impressed with the management of this ...
# 6  rediculous spend 9 on buffet without drink and...
# 7  way overpriced for a very small buffet with me...
# 8  yummy pizza this location is new and clean the...
# 9  this place is discussing and nothing it clean ...

# %% [markdown]
# ### Removing stop words

# %%
df["no_stopwords"] = df['punctuation'].apply(lambda x: ' '.join (word for word in x.split() if word not in stop_words))
df
#first split the words
##then check if the word is in stop_words
#if the word is not a stop word, join them back
# Out:
#                                              reviews  word_count  char_count  \
# 0  It's a thursday afternoon and this Cici's is c...          95         522
# 1  What a joke of a business surprise to see them...          24         122
# 2  love this place, i totally recommend to all pi...          24         114
# 3  Everyone knows that this place has subpar pizz...         222        1203
# 4  I have not been to a cc pizza since I was in c...         102         535
# 5  I am so impressed with the management of this ...         131         673
# 6  Rediculous, spend $9 on buffet without drink a...          35         191
# 7  Way overpriced for a very small buffet with me...          48         282
# 8  Yummy pizza. This location is new and clean. T...          33         187
# 9  This place is discussing and nothing it clean ...          53         283
#
#    average_word_length  stopword_count  stopword_rate  \
# 0             4.505263              46       0.484211
# 1             4.125000              11       0.458333
# 2             3.791667              13       0.541667
# 3             4.364865             117       0.527027
# 4             4.254902              56       0.549020
# 5             4.145038              70       0.534351
# 6             4.457143              13       0.371429
# 7             4.895833              19       0.395833
# 8             4.696970              12       0.363636
# 9             4.358491              26       0.490566
#
#                                            lowercase  \
# 0  it's a thursday afternoon and this cici's is c...
# 1  what a joke of a business surprise to see them...
# 2  love this place, i totally recommend to all pi...
# 3  everyone knows that this place has subpar pizz...
# 4  i have not been to a cc pizza since i was in c...
# 5  i am so impressed with the management of this ...
# 6  rediculous, spend $9 on buffet without drink a...
# 7  way overpriced for a very small buffet with me...
# 8  yummy pizza. this location is new and clean. t...
# 9  this place is discussing and nothing it clean ...
#
#                                          punctuation  \
# 0  its a thursday afternoon and this cicis is cle...
# 1  what a joke of a business surprise to see them...
# 2  love this place i totally recommend to all piz...
# 3  everyone knows that this place has subpar pizz...
# 4  i have not been to a cc pizza since i was in c...
# 5  i am so impressed with the management of this ...
# 6  rediculous spend 9 on buffet without drink and...
# 7  way overpriced for a very small buffet with me...
# 8  yummy pizza this location is new and clean the...
# 9  this place is discussing and nothing it clean ...
#
#                                         no_stopwords
# 0  thursday afternoon cicis clean wellstocked run...
# 1  joke business surprise see still business ever...
# 2  love place totally recommend pizza lovers come...
# 3  everyone knows place subpar pizza sometimes pa...
# 4  cc pizza since college springfield missouri tw...
# 5  impressed management shop greeted walked paid ...
# 6  rediculous spend 9 buffet without drink cant g...
# 7  way overpriced small buffet mediocre pizza pas...
# 8  yummy pizza location new clean let request piz...
# 9  place discussing nothing clean dont wash trys ...

# %%
#lets look at the number of words in the updated reviews

df['no_stopwords'].apply(lambda x: len(x.split()))
# Out:
# 0     48
# 1     13
# 2     11
# 3    106
# 4     45
# 5     59
# 6     21
# 7     28
# 8     20
# 9     28
# Name: no_stopwords, dtype: int64

# %% [markdown]
# ### Removing more manual words
#
# --this step shall be ignored if used for live data
#
# we will remove more words that add no value to the sentiment manually

# %%
#Lets join all the reviews into a one giant sentence and convert that into an array
word_array = " ".join(df["no_stopwords"]).split()
word_array

#This is the array of every single word in our reviews
# Out:
# ['thursday',
#  'afternoon',
#  'cicis',
#  'clean',
#  'wellstocked',
#  'run',
#  'solo',
#  'one',
#  'lady',
#  'country',
#  'little',
#  'loud',
#  'hey',
#  'missouri',
#  'got',
#  'lunch',
#  'got',
#  'chill',
#  'time',
#  'itedit',
#  'management',
#  'owners',
#  'womens',
#  'restroom',
#  'needs',
#  'tlc',
#  'order',
#  'feel',
#  'like',
#  'safe',
#  'comfortable',
#  'space',
#  'seats',
#  'replaced',
#  'one',
#  'walls',
#  'needs',
#  'reaffixed',
#  'door',
#  'hurts',
#  'someone',
#  'screws',
#  'sticking',
#  'easily',
#  'accessible',
#  'space',
#  'frequented',
#  'children',
#  'joke',
#  'business',
#  'surprise',
#  'see',
#  'still',
#  'business',
#  'every',
#  'time',
#  'go',
#  'closing',
#  'early',
#  'pizza',
#  'lame',
#  'love',
#  'place',
#  'totally',
#  'recommend',
#  'pizza',
#  'lovers',
#  'come',
#  'school',
#  'trip',
#  'still',
#  'love',
#  'everyone',
#  'knows',
#  'place',
#  'subpar',
#  'pizza',
#  'sometimes',
#  'parents',
#  'look',
#  'past',
#  'cheap',
#  'price',
#  'biggest',
#  'gripes',
#  'dont',
#  'take',
#  'responsibility',
#  'everything',
#  'building',
#  'something',
#  'simple',
#  'token',
#  'machine',
#  'token',
#  'machine',
#  'buy',
#  'tokens',
#  'one',
#  'would',
#  'think',
#  'video',
#  'games',
#  'would',
#  'run',
#  'tokens',
#  'finally',
#  'approach',
#  'video',
#  'games',
#  'dont',
#  'run',
#  'tokens',
#  'buy',
#  'card',
#  'charge',
#  'play',
#  'video',
#  'games',
#  'approached',
#  'manager',
#  'getting',
#  'refund',
#  'would',
#  'take',
#  'refund',
#  'buy',
#  'video',
#  'game',
#  'cards',
#  'got',
#  'answer',
#  'n',
#  'ot',
#  'owned',
#  'cities',
#  'dont',
#  'take',
#  'responsibility',
#  'video',
#  'games',
#  'since',
#  'outside',
#  'company',
#  'runs',
#  'owns',
#  'difficult',
#  'would',
#  'give',
#  'refund',
#  'whoever',
#  'happens',
#  'work',
#  'refunds',
#  'give',
#  'company',
#  'allow',
#  'bring',
#  'video',
#  'games',
#  'restaurant',
#  'instead',
#  'would',
#  'rather',
#  'let',
#  'lose',
#  'business',
#  'type',
#  'thing',
#  'create',
#  'ton',
#  'one',
#  'time',
#  'customers',
#  'definitely',
#  'create',
#  'repeat',
#  'customers',
#  'cc',
#  'pizza',
#  'since',
#  'college',
#  'springfield',
#  'missouri',
#  'two',
#  'decades',
#  'ago',
#  'quite',
#  'honestly',
#  'much',
#  'changed',
#  'say',
#  'back',
#  'day',
#  'pasta',
#  'salad',
#  'bar',
#  'extensive',
#  'enjoyed',
#  'every',
#  'minute',
#  'reliving',
#  'nostalgia',
#  'college',
#  'years',
#  'manager',
#  'working',
#  'fantastic',
#  'really',
#  'nice',
#  'made',
#  'favorite',
#  'pizza',
#  'barbecue',
#  'beef',
#  'pizza',
#  'enjoyed',
#  'thoroughly',
#  'wonderful',
#  'experience',
#  'clean',
#  'nice',
#  'restaurant',
#  'impressed',
#  'management',
#  'shop',
#  'greeted',
#  'walked',
#  'paid',
#  'buffet',
#  'asked',
#  'kind',
#  'pizza',
#  'would',
#  'like',
#  'jokingly',
#  'said',
#  'anchovy',
#  'smile',
#  'said',
#  'could',
#  'make',
#  'one',
#  'said',
#  'requested',
#  'often',
#  'would',
#  'make',
#  'personal',
#  'pizza',
#  'bowl',
#  'soup',
#  'salad',
#  'waited',
#  'soup',
#  'hot',
#  'salad',
#  'fresh',
#  'cold',
#  'worth',
#  'price',
#  'right',
#  'watching',
#  'crew',
#  'work',
#  'engaged',
#  'positive',
#  'busy',
#  'manager',
#  'brought',
#  'anchovy',
#  'pizza',
#  'amazing',
#  'hot',
#  'fresh',
#  'delicious',
#  'awhile',
#  'since',
#  'already',
#  'planning',
#  'next',
#  'trip',
#  'rediculous',
#  'spend',
#  '9',
#  'buffet',
#  'without',
#  'drink',
#  'cant',
#  'get',
#  'cheese',
#  'salad',
#  'el',
#  'cheapo',
#  'paper',
#  'thin',
#  'pizza',
#  'people',
#  'lettuce',
#  'iceberg',
#  'chunky',
#  'brown',
#  'fan',
#  'way',
#  'overpriced',
#  'small',
#  'buffet',
#  'mediocre',
#  'pizza',
#  'pasta',
#  'desert',
#  'none',
#  'three',
#  'four',
#  'options',
#  'really',
#  'desertservice',
#  'quick',
#  'easy',
#  'place',
#  'seemed',
#  'pretty',
#  'clean',
#  'however',
#  'theres',
#  'anything',
#  'else',
#  'really',
#  'compliment',
#  'give',
#  'thumbs',
#  'yummy',
#  'pizza',
#  'location',
#  'new',
#  'clean',
#  'let',
#  'request',
#  'pizzas',
#  'toppings',
#  'like',
#  'ready',
#  '10',
#  'minutes',
#  'gave',
#  'lot',
#  'varieties',
#  'ready',
#  'freshsalad',
#  'bar',
#  'available',
#  'place',
#  'discussing',
#  'nothing',
#  'clean',
#  'dont',
#  'wash',
#  'trys',
#  'cook',
#  'pizzas',
#  'unless',
#  'falls',
#  'floor',
#  'hasnt',
#  'cleaned',
#  'years',
#  'theres',
#  'mold',
#  'everywhere',
#  'failed',
#  '3',
#  'straight',
#  'inspections',
#  'spray',
#  'paint',
#  'vents',
#  'pass',
#  'next',
#  'sad']

# %%
#creating a frequency count of strings
pd.Series(word_array).value_counts()[:30]


#this gives us count of how many times a word is occuring in all the reviews
#looking at the top 30 words
# Out:
# pizza        12
# would         7
# video         6
# games         5
# clean         5
# one           5
# place         4
# dont          4
# salad         4
# said          3
# like          3
# buy           3
# give          3
# take          3
# manager       3
# business      3
# tokens        3
# since         3
# time          3
# buffet        3
# got           3
# refund        3
# run           3
# really        3
# still         2
# hot           2
# customers     2
# fresh         2
# work          2
# price         2
# dtype: int64

# %%
#lets create a list of words that are repeated but not adding value to the sentiment. This is very subjective
other_stop_words = []
'''for special situations, we may ignore our manually chosen words'''
# Out:
# 'for special situations, we may ignore our manually chosen words'

# %%
#removing the words in the list above from review sentences

df['clean_review'] = df['no_stopwords'].apply(lambda x: " ".join(word for word in x.split() if word not in other_stop_words))
df
# Out:
#                                              reviews  word_count  char_count  \
# 0  It's a thursday afternoon and this Cici's is c...          95         522
# 1  What a joke of a business surprise to see them...          24         122
# 2  love this place, i totally recommend to all pi...          24         114
# 3  Everyone knows that this place has subpar pizz...         222        1203
# 4  I have not been to a cc pizza since I was in c...         102         535
# 5  I am so impressed with the management of this ...         131         673
# 6  Rediculous, spend $9 on buffet without drink a...          35         191
# 7  Way overpriced for a very small buffet with me...          48         282
# 8  Yummy pizza. This location is new and clean. T...          33         187
# 9  This place is discussing and nothing it clean ...          53         283
#
#    average_word_length  stopword_count  stopword_rate  \
# 0             4.505263              46       0.484211
# 1             4.125000              11       0.458333
# 2             3.791667              13       0.541667
# 3             4.364865             117       0.527027
# 4             4.254902              56       0.549020
# 5             4.145038              70       0.534351
# 6             4.457143              13       0.371429
# 7             4.895833              19       0.395833
# 8             4.696970              12       0.363636
# 9             4.358491              26       0.490566
#
#                                            lowercase  \
# 0  it's a thursday afternoon and this cici's is c...
# 1  what a joke of a business surprise to see them...
# 2  love this place, i totally recommend to all pi...
# 3  everyone knows that this place has subpar pizz...
# 4  i have not been to a cc pizza since i was in c...
# 5  i am so impressed with the management of this ...
# 6  rediculous, spend $9 on buffet without drink a...
# 7  way overpriced for a very small buffet with me...
# 8  yummy pizza. this location is new and clean. t...
# 9  this place is discussing and nothing it clean ...
#
#                                          punctuation  \
# 0  its a thursday afternoon and this cicis is cle...
# 1  what a joke of a business surprise to see them...
# 2  love this place i totally recommend to all piz...
# 3  everyone knows that this place has subpar pizz...
# 4  i have not been to a cc pizza since i was in c...
# 5  i am so impressed with the management of this ...
# 6  rediculous spend 9 on buffet without drink and...
# 7  way overpriced for a very small buffet with me...
# 8  yummy pizza this location is new and clean the...
# 9  this place is discussing and nothing it clean ...
#
#                                         no_stopwords  \
# 0  thursday afternoon cicis clean wellstocked run...
# 1  joke business surprise see still business ever...
# 2  love place totally recommend pizza lovers come...
# 3  everyone knows place subpar pizza sometimes pa...
# 4  cc pizza since college springfield missouri tw...
# 5  impressed management shop greeted walked paid ...
# 6  rediculous spend 9 buffet without drink cant g...
# 7  way overpriced small buffet mediocre pizza pas...
# 8  yummy pizza location new clean let request piz...
# 9  place discussing nothing clean dont wash trys ...
#
#                                         clean_review
# 0  thursday afternoon cicis clean wellstocked run...
# 1  joke business surprise see still business ever...
# 2  love place totally recommend pizza lovers come...
# 3  everyone knows place subpar pizza sometimes pa...
# 4  cc pizza since college springfield missouri tw...
# 5  impressed management shop greeted walked paid ...
# 6  rediculous spend 9 buffet without drink cant g...
# 7  way overpriced small buffet mediocre pizza pas...
# 8  yummy pizza location new clean let request piz...
# 9  place discussing nothing clean dont wash trys ...

# %%
 #lets look at the number of words in the updated reviews

df['no_stopwords'].apply(lambda x: len(x.split()))
# Out:
# 0     48
# 1     13
# 2     11
# 3    106
# 4     45
# 5     59
# 6     21
# 7     28
# 8     20
# 9     28
# Name: no_stopwords, dtype: int64

# %% [markdown]
# at this point the data is ready

# %% [markdown]
# .
#
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
#
# # Lemmatization

# %% [markdown]
# Lemmatization is a natural language processing (NLP) technique that involves reducing words to their base or root form.
# The base form is called a "lemma."
#
# Lemmatization is often used in text processing and analysis to normalize words. It helps in reducing the dimensionality of the feature space and can improve the performance of tasks like text classification, sentiment analysis, and information retrieval.
#
# In contrast to lemmatization, stemming is another technique that involves reducing words to their root or base form, but it may not always result in a valid word. Lemmatization tends to be more linguistically accurate as it considers the context and aims to produce valid words.
#
# "running" → lemma: "run"
# "better" → lemma: "good"
# "mice" → lemma: "mouse"

# %% [markdown]
# We will use textblob to lemmatize

# %%
#again I didn't have the textblob package in my environment so had to install it from conda
from textblob import Word

# %% [markdown]
# TextBlob is a Python library for processing textual data. It provides a simple API for common natural language processing (NLP) tasks, such as part-of-speech tagging, noun phrase extraction, sentiment analysis, classification, translation, and more. TextBlob is built on top of NLTK (Natural Language Toolkit) and Pattern libraries.

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /Users/supg/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#we need to loop through each word and lemmatize them
df['lemmatized'] = df['clean_review'].apply(lambda x: " ".join(Word(word).lemmatize() for word in x.split()))
df

#first we need to change each word into textblob word object
# Out:
#                                              reviews  word_count  char_count  \
# 0  It's a thursday afternoon and this Cici's is c...          95         522
# 1  What a joke of a business surprise to see them...          24         122
# 2  love this place, i totally recommend to all pi...          24         114
# 3  Everyone knows that this place has subpar pizz...         222        1203
# 4  I have not been to a cc pizza since I was in c...         102         535
# 5  I am so impressed with the management of this ...         131         673
# 6  Rediculous, spend $9 on buffet without drink a...          35         191
# 7  Way overpriced for a very small buffet with me...          48         282
# 8  Yummy pizza. This location is new and clean. T...          33         187
# 9  This place is discussing and nothing it clean ...          53         283
#
#    average_word_length  stopword_count  stopword_rate  \
# 0             4.505263              46       0.484211
# 1             4.125000              11       0.458333
# 2             3.791667              13       0.541667
# 3             4.364865             117       0.527027
# 4             4.254902              56       0.549020
# 5             4.145038              70       0.534351
# 6             4.457143              13       0.371429
# 7             4.895833              19       0.395833
# 8             4.696970              12       0.363636
# 9             4.358491              26       0.490566
#
#                                            lowercase  \
# 0  it's a thursday afternoon and this cici's is c...
# 1  what a joke of a business surprise to see them...
# 2  love this place, i totally recommend to all pi...
# 3  everyone knows that this place has subpar pizz...
# 4  i have not been to a cc pizza since i was in c...
# 5  i am so impressed with the management of this ...
# 6  rediculous, spend $9 on buffet without drink a...
# 7  way overpriced for a very small buffet with me...
# 8  yummy pizza. this location is new and clean. t...
# 9  this place is discussing and nothing it clean ...
#
#                                          punctuation  \
# 0  its a thursday afternoon and this cicis is cle...
# 1  what a joke of a business surprise to see them...
# 2  love this place i totally recommend to all piz...
# 3  everyone knows that this place has subpar pizz...
# 4  i have not been to a cc pizza since i was in c...
# 5  i am so impressed with the management of this ...
# 6  rediculous spend 9 on buffet without drink and...
# 7  way overpriced for a very small buffet with me...
# 8  yummy pizza this location is new and clean the...
# 9  this place is discussing and nothing it clean ...
#
#                                         no_stopwords  \
# 0  thursday afternoon cicis clean wellstocked run...
# 1  joke business surprise see still business ever...
# 2  love place totally recommend pizza lovers come...
# 3  everyone knows place subpar pizza sometimes pa...
# 4  cc pizza since college springfield missouri tw...
# 5  impressed management shop greeted walked paid ...
# 6  rediculous spend 9 buffet without drink cant g...
# 7  way overpriced small buffet mediocre pizza pas...
# 8  yummy pizza location new clean let request piz...
# 9  place discussing nothing clean dont wash trys ...
#
#                                         clean_review  \
# 0  thursday afternoon cicis clean wellstocked run...
# 1  joke business surprise see still business ever...
# 2  love place totally recommend pizza lovers come...
# 3  everyone knows place subpar pizza sometimes pa...
# 4  cc pizza since college springfield missouri tw...
# 5  impressed management shop greeted walked paid ...
# 6  rediculous spend 9 buffet without drink cant g...
# 7  way overpriced small buffet mediocre pizza pas...
# 8  yummy pizza location new clean let request piz...
# 9  place discussing nothing clean dont wash trys ...
#
#                                           lemmatized
# 0  thursday afternoon cicis clean wellstocked run...
# 1  joke business surprise see still business ever...
# 2  love place totally recommend pizza lover come ...
# 3  everyone know place subpar pizza sometimes par...
# 4  cc pizza since college springfield missouri tw...
# 5  impressed management shop greeted walked paid ...
# 6  rediculous spend 9 buffet without drink cant g...
# 7  way overpriced small buffet mediocre pizza pas...
# 8  yummy pizza location new clean let request piz...
# 9  place discussing nothing clean dont wash try c...

# %%
df.drop(['lowercase','punctuation','no_stopwords','clean_review'], axis = 1, inplace = True)

# %% [markdown]
# Now its ready for sentiment analysis

# %%
df
# Out:
#                                              reviews  word_count  char_count  \
# 0  It's a thursday afternoon and this Cici's is c...          95         522
# 1  What a joke of a business surprise to see them...          24         122
# 2  love this place, i totally recommend to all pi...          24         114
# 3  Everyone knows that this place has subpar pizz...         222        1203
# 4  I have not been to a cc pizza since I was in c...         102         535
# 5  I am so impressed with the management of this ...         131         673
# 6  Rediculous, spend $9 on buffet without drink a...          35         191
# 7  Way overpriced for a very small buffet with me...          48         282
# 8  Yummy pizza. This location is new and clean. T...          33         187
# 9  This place is discussing and nothing it clean ...          53         283
#
#    average_word_length  stopword_count  stopword_rate  \
# 0             4.505263              46       0.484211
# 1             4.125000              11       0.458333
# 2             3.791667              13       0.541667
# 3             4.364865             117       0.527027
# 4             4.254902              56       0.549020
# 5             4.145038              70       0.534351
# 6             4.457143              13       0.371429
# 7             4.895833              19       0.395833
# 8             4.696970              12       0.363636
# 9             4.358491              26       0.490566
#
#                                           lemmatized
# 0  thursday afternoon cicis clean wellstocked run...
# 1  joke business surprise see still business ever...
# 2  love place totally recommend pizza lover come ...
# 3  everyone know place subpar pizza sometimes par...
# 4  cc pizza since college springfield missouri tw...
# 5  impressed management shop greeted walked paid ...
# 6  rediculous spend 9 buffet without drink cant g...
# 7  way overpriced small buffet mediocre pizza pas...
# 8  yummy pizza location new clean let request piz...
# 9  place discussing nothing clean dont wash try c...

# %% [markdown]
# .
#
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# # Sentiment Analysis

# %% [markdown]
# We will use TextBlob package from textblob to calculate sentiment analysis
#
# TextBlob gives use 2 metrics:
# 1) Polarity : is a numerical value indicating the sentiment of the text. It ranges from -1 to 1, where -1 represents a negative sentiment, 1 represents a positive sentiment, and 0 represents a neutral sentiment.
#
# 2) Subjectivity: Subjectivity is a numerical value indicating the subjectiveness of the text. It ranges from 0 to 1, where 0 is very objective (factual) and 1 is very subjective (opinionated or emotional).

# %%
from textblob import TextBlob

# %%
df['lemmatized'].apply(lambda x: TextBlob(x).sentiment)
#the first value is polarity and later one is subjectivity
# Out:
# 0       (0.2590277777777778, 0.6124999999999999)
# 1                                  (-0.2, 0.525)
# 2                     (0.3333333333333333, 0.65)
# 3    (-0.21153846153846154, 0.48131868131868133)
# 4       (0.4242424242424242, 0.6848484848484848)
# 5        (0.3070616883116883, 0.586323051948052)
# 6                     (-0.4, 0.8500000000000001)
# 7      (0.12916666666666665, 0.6041666666666666)
# 8       (0.2606060606060606, 0.5109090909090909)
# 9                   (-0.08666666666666666, 0.48)
# Name: lemmatized, dtype: object

# %%
df['polarity'] = df['lemmatized'].apply(lambda x: TextBlob(x).sentiment[0])
df
# Out:
#                                              reviews  word_count  char_count  \
# 0  It's a thursday afternoon and this Cici's is c...          95         522
# 1  What a joke of a business surprise to see them...          24         122
# 2  love this place, i totally recommend to all pi...          24         114
# 3  Everyone knows that this place has subpar pizz...         222        1203
# 4  I have not been to a cc pizza since I was in c...         102         535
# 5  I am so impressed with the management of this ...         131         673
# 6  Rediculous, spend $9 on buffet without drink a...          35         191
# 7  Way overpriced for a very small buffet with me...          48         282
# 8  Yummy pizza. This location is new and clean. T...          33         187
# 9  This place is discussing and nothing it clean ...          53         283
#
#    average_word_length  stopword_count  stopword_rate  \
# 0             4.505263              46       0.484211
# 1             4.125000              11       0.458333
# 2             3.791667              13       0.541667
# 3             4.364865             117       0.527027
# 4             4.254902              56       0.549020
# 5             4.145038              70       0.534351
# 6             4.457143              13       0.371429
# 7             4.895833              19       0.395833
# 8             4.696970              12       0.363636
# 9             4.358491              26       0.490566
#
#                                           lemmatized  polarity
# 0  thursday afternoon cicis clean wellstocked run...  0.259028
# 1  joke business surprise see still business ever... -0.200000
# 2  love place totally recommend pizza lover come ...  0.333333
# 3  everyone know place subpar pizza sometimes par... -0.211538
# 4  cc pizza since college springfield missouri tw...  0.424242
# 5  impressed management shop greeted walked paid ...  0.307062
# 6  rediculous spend 9 buffet without drink cant g... -0.400000
# 7  way overpriced small buffet mediocre pizza pas...  0.129167
# 8  yummy pizza location new clean let request piz...  0.260606
# 9  place discussing nothing clean dont wash try c... -0.086667

# %%
df['subjectivity'] = df['lemmatized'].apply(lambda x: TextBlob(x).sentiment[1])
df
# Out:
#                                              reviews  word_count  char_count  \
# 0  It's a thursday afternoon and this Cici's is c...          95         522
# 1  What a joke of a business surprise to see them...          24         122
# 2  love this place, i totally recommend to all pi...          24         114
# 3  Everyone knows that this place has subpar pizz...         222        1203
# 4  I have not been to a cc pizza since I was in c...         102         535
# 5  I am so impressed with the management of this ...         131         673
# 6  Rediculous, spend $9 on buffet without drink a...          35         191
# 7  Way overpriced for a very small buffet with me...          48         282
# 8  Yummy pizza. This location is new and clean. T...          33         187
# 9  This place is discussing and nothing it clean ...          53         283
#
#    average_word_length  stopword_count  stopword_rate  \
# 0             4.505263              46       0.484211
# 1             4.125000              11       0.458333
# 2             3.791667              13       0.541667
# 3             4.364865             117       0.527027
# 4             4.254902              56       0.549020
# 5             4.145038              70       0.534351
# 6             4.457143              13       0.371429
# 7             4.895833              19       0.395833
# 8             4.696970              12       0.363636
# 9             4.358491              26       0.490566
#
#                                           lemmatized  polarity  subjectivity
# 0  thursday afternoon cicis clean wellstocked run...  0.259028      0.612500
# 1  joke business surprise see still business ever... -0.200000      0.525000
# 2  love place totally recommend pizza lover come ...  0.333333      0.650000
# 3  everyone know place subpar pizza sometimes par... -0.211538      0.481319
# 4  cc pizza since college springfield missouri tw...  0.424242      0.684848
# 5  impressed management shop greeted walked paid ...  0.307062      0.586323
# 6  rediculous spend 9 buffet without drink cant g... -0.400000      0.850000
# 7  way overpriced small buffet mediocre pizza pas...  0.129167      0.604167
# 8  yummy pizza location new clean let request piz...  0.260606      0.510909
# 9  place discussing nothing clean dont wash try c... -0.086667      0.480000

# %%
df.sort_values(by = 'polarity', ascending = False)
# Out:
#                                              reviews  word_count  char_count  \
# 4  I have not been to a cc pizza since I was in c...         102         535
# 2  love this place, i totally recommend to all pi...          24         114
# 5  I am so impressed with the management of this ...         131         673
# 8  Yummy pizza. This location is new and clean. T...          33         187
# 0  It's a thursday afternoon and this Cici's is c...          95         522
# 7  Way overpriced for a very small buffet with me...          48         282
# 9  This place is discussing and nothing it clean ...          53         283
# 1  What a joke of a business surprise to see them...          24         122
# 3  Everyone knows that this place has subpar pizz...         222        1203
# 6  Rediculous, spend $9 on buffet without drink a...          35         191
#
#    average_word_length  stopword_count  stopword_rate  \
# 4             4.254902              56       0.549020
# 2             3.791667              13       0.541667
# 5             4.145038              70       0.534351
# 8             4.696970              12       0.363636
# 0             4.505263              46       0.484211
# 7             4.895833              19       0.395833
# 9             4.358491              26       0.490566
# 1             4.125000              11       0.458333
# 3             4.364865             117       0.527027
# 6             4.457143              13       0.371429
#
#                                           lemmatized  polarity  subjectivity
# 4  cc pizza since college springfield missouri tw...  0.424242      0.684848
# 2  love place totally recommend pizza lover come ...  0.333333      0.650000
# 5  impressed management shop greeted walked paid ...  0.307062      0.586323
# 8  yummy pizza location new clean let request piz...  0.260606      0.510909
# 0  thursday afternoon cicis clean wellstocked run...  0.259028      0.612500
# 7  way overpriced small buffet mediocre pizza pas...  0.129167      0.604167
# 9  place discussing nothing clean dont wash try c... -0.086667      0.480000
# 1  joke business surprise see still business ever... -0.200000      0.525000
# 3  everyone know place subpar pizza sometimes par... -0.211538      0.481319
# 6  rediculous spend 9 buffet without drink cant g... -0.400000      0.850000

# %% [markdown]
# # Based on this, we can identify sentiments of reviews
